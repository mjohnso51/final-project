# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from copy import deepcopy

# %%
rklb = pd.read_csv("C:\\Users\\cello\\Git\\final-project\\Resources\\rklb-price.csv")
rklb.head()
# Out:
#          Date   Open    High    Low  Close  Adj Close  Volume
# 0  2020-11-24  9.750   9.750  9.744  9.744      9.744     900
# 1  2020-11-25  9.744   9.744  9.744  9.744      9.744     100
# 2  2020-11-27  9.800   9.820  9.800  9.820      9.820    4500
# 3  2020-11-30  9.820  10.800  9.720  9.950      9.950   53300
# 4  2020-12-01  9.873   9.970  9.873  9.970      9.970    2000

# %%
rklb = rklb[['Date','Close']]
rklb.head()
# Out:
#          Date  Close
# 0  2020-11-24  9.744
# 1  2020-11-25  9.744
# 2  2020-11-27  9.820
# 3  2020-11-30  9.950
# 4  2020-12-01  9.970

# %%
def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('2022-11-24')
datetime_object
# Out:
# datetime.datetime(2022, 11, 24, 0, 0)

# %%
rklb['Date'] = rklb['Date'].apply(str_to_datetime)
rklb['Date']
# Out:
# 0     2020-11-24
# 1     2020-11-25
# 2     2020-11-27
# 3     2020-11-30
# 4     2020-12-01
#          ...
# 697   2023-09-05
# 698   2023-09-06
# 699   2023-09-07
# 700   2023-09-08
# 701   2023-09-11
# Name: Date, Length: 702, dtype: datetime64[ns]

# %%
rklb.index = rklb.pop('Date')
rklb.head()
# Out:
#             Close
# Date
# 2020-11-24  9.744
# 2020-11-25  9.744
# 2020-11-27  9.820
# 2020-11-30  9.950
# 2020-12-01  9.970

# %%
plt.plot(rklb.index, rklb['Close'])

# %%
def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(rklb, 
                                '2020-11-30', 
                                '2023-09-11', 
                                n=3)
windowed_df
# Out:
#     Target Date  Target-3  Target-2  Target-1  Target
# 0    2020-11-30     9.744     9.744      9.82    9.95
# 1    2020-12-01     9.744     9.820      9.95    9.97
# 2    2020-12-02     9.820     9.950      9.97   10.05
# 3    2020-12-03     9.950     9.970     10.05   10.05
# 4    2020-12-04     9.970    10.050     10.05   10.06
# ..          ...       ...       ...       ...     ...
# 694  2023-09-05     6.380     6.310      6.34    6.53
# 695  2023-09-06     6.310     6.340      6.53    6.41
# 696  2023-09-07     6.340     6.530      6.41    6.32
# 697  2023-09-08     6.530     6.410      6.32    6.20
# 698  2023-09-11     6.410     6.320      6.20    6.04
#
# [699 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((699,), (699, 3, 1), (699,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 2s 23ms/step - loss: 74.1037 - mean_absolute_error: 7.8884 - val_loss: 6.7398 - val_mean_absolute_error: 2.5851
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 35.7545 - mean_absolute_error: 5.0598 - val_loss: 0.6581 - val_mean_absolute_error: 0.7960
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 8.3889 - mean_absolute_error: 2.3192 - val_loss: 13.4406 - val_mean_absolute_error: 3.6618
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 4.9300 - mean_absolute_error: 1.7763 - val_loss: 2.0194 - val_mean_absolute_error: 1.4107
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 2.7642 - mean_absolute_error: 1.2221 - val_loss: 0.7712 - val_mean_absolute_error: 0.8575
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.2220 - mean_absolute_error: 0.7149 - val_loss: 0.0354 - val_mean_absolute_error: 0.1404
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6459 - mean_absolute_error: 0.4964 - val_loss: 0.0572 - val_mean_absolute_error: 0.2073
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4747 - mean_absolute_error: 0.4440 - val_loss: 0.0973 - val_mean_absolute_error: 0.2822
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3861 - mean_absolute_error: 0.4092 - val_loss: 0.1013 - val_mean_absolute_error: 0.2903
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3460 - mean_absolute_error: 0.3756 - val_loss: 0.0632 - val_mean_absolute_error: 0.2223
# Epoch 11/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3272 - mean_absolute_error: 0.3585 - val_loss: 0.0769 - val_mean_absolute_error: 0.2491
# Epoch 12/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2908 - mean_absolute_error: 0.3269 - val_loss: 0.0394 - val_mean_absolute_error: 0.1677
# Epoch 13/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2773 - mean_absolute_error: 0.3167 - val_loss: 0.0405 - val_mean_absolute_error: 0.1712
# Epoch 14/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2681 - mean_absolute_error: 0.3088 - val_loss: 0.0225 - val_mean_absolute_error: 0.1166
# Epoch 15/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2567 - mean_absolute_error: 0.2870 - val_loss: 0.0187 - val_mean_absolute_error: 0.1049
# Epoch 16/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2632 - mean_absolute_error: 0.2950 - val_loss: 0.0187 - val_mean_absolute_error: 0.1047
# Epoch 17/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2492 - mean_absolute_error: 0.2882 - val_loss: 0.0258 - val_mean_absolute_error: 0.1288
# Epoch 18/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2570 - mean_absolute_error: 0.3044 - val_loss: 0.0179 - val_mean_absolute_error: 0.1024
# Epoch 19/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2454 - mean_absolute_error: 0.2859 - val_loss: 0.0194 - val_mean_absolute_error: 0.1053
# Epoch 20/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2573 - mean_absolute_error: 0.2948 - val_loss: 0.0196 - val_mean_absolute_error: 0.1083
# Epoch 21/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2547 - mean_absolute_error: 0.2908 - val_loss: 0.0210 - val_mean_absolute_error: 0.1114
# Epoch 22/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2481 - mean_absolute_error: 0.2816 - val_loss: 0.0175 - val_mean_absolute_error: 0.0995
# Epoch 23/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2437 - mean_absolute_error: 0.2874 - val_loss: 0.0189 - val_mean_absolute_error: 0.1035
# Epoch 24/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2484 - mean_absolute_error: 0.2879 - val_loss: 0.0215 - val_mean_absolute_error: 0.1150
# Epoch 25/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2511 - mean_absolute_error: 0.2921 - val_loss: 0.0185 - val_mean_absolute_error: 0.1022
# Epoch 26/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2404 - mean_absolute_error: 0.2769 - val_loss: 0.0217 - val_mean_absolute_error: 0.1162
# Epoch 27/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2661 - mean_absolute_error: 0.3160 - val_loss: 0.0235 - val_mean_absolute_error: 0.1202
# Epoch 28/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2603 - mean_absolute_error: 0.3013 - val_loss: 0.0173 - val_mean_absolute_error: 0.0990
# Epoch 29/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2629 - mean_absolute_error: 0.3103 - val_loss: 0.0171 - val_mean_absolute_error: 0.0998
# Epoch 30/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2399 - mean_absolute_error: 0.2881 - val_loss: 0.0168 - val_mean_absolute_error: 0.0978
# Epoch 31/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2480 - mean_absolute_error: 0.2809 - val_loss: 0.0226 - val_mean_absolute_error: 0.1202
# Epoch 32/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2556 - mean_absolute_error: 0.2875 - val_loss: 0.0165 - val_mean_absolute_error: 0.0970
# Epoch 33/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2339 - mean_absolute_error: 0.2710 - val_loss: 0.0182 - val_mean_absolute_error: 0.1044
# Epoch 34/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2549 - mean_absolute_error: 0.2963 - val_loss: 0.0228 - val_mean_absolute_error: 0.1169
# Epoch 35/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2525 - mean_absolute_error: 0.3009 - val_loss: 0.0300 - val_mean_absolute_error: 0.1417
# Epoch 36/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2482 - mean_absolute_error: 0.3121 - val_loss: 0.0164 - val_mean_absolute_error: 0.0968
# Epoch 37/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2392 - mean_absolute_error: 0.2767 - val_loss: 0.0166 - val_mean_absolute_error: 0.0974
# Epoch 38/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2322 - mean_absolute_error: 0.2698 - val_loss: 0.0240 - val_mean_absolute_error: 0.1250
# Epoch 39/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2486 - mean_absolute_error: 0.2838 - val_loss: 0.0174 - val_mean_absolute_error: 0.1018
# Epoch 40/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2392 - mean_absolute_error: 0.2945 - val_loss: 0.0211 - val_mean_absolute_error: 0.1160
# Epoch 41/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2455 - mean_absolute_error: 0.2885 - val_loss: 0.0164 - val_mean_absolute_error: 0.0969
# Epoch 42/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2383 - mean_absolute_error: 0.2692 - val_loss: 0.0195 - val_mean_absolute_error: 0.1103
# Epoch 43/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2472 - mean_absolute_error: 0.2803 - val_loss: 0.0190 - val_mean_absolute_error: 0.1085
# Epoch 44/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2370 - mean_absolute_error: 0.2729 - val_loss: 0.0164 - val_mean_absolute_error: 0.0978
# Epoch 45/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2401 - mean_absolute_error: 0.2801 - val_loss: 0.0182 - val_mean_absolute_error: 0.1014
# Epoch 46/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2454 - mean_absolute_error: 0.2892 - val_loss: 0.0198 - val_mean_absolute_error: 0.1113
# Epoch 47/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2309 - mean_absolute_error: 0.2693 - val_loss: 0.0176 - val_mean_absolute_error: 0.1029
# Epoch 48/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2382 - mean_absolute_error: 0.2705 - val_loss: 0.0161 - val_mean_absolute_error: 0.0968
# Epoch 49/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2516 - mean_absolute_error: 0.2982 - val_loss: 0.0162 - val_mean_absolute_error: 0.0964
# Epoch 50/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2441 - mean_absolute_error: 0.2866 - val_loss: 0.0161 - val_mean_absolute_error: 0.0966
# Epoch 51/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2372 - mean_absolute_error: 0.2787 - val_loss: 0.0187 - val_mean_absolute_error: 0.1075
# Epoch 52/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2381 - mean_absolute_error: 0.2839 - val_loss: 0.0195 - val_mean_absolute_error: 0.1054
# Epoch 53/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2332 - mean_absolute_error: 0.2713 - val_loss: 0.0315 - val_mean_absolute_error: 0.1472
# Epoch 54/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2619 - mean_absolute_error: 0.2970 - val_loss: 0.0188 - val_mean_absolute_error: 0.1081
# Epoch 55/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2332 - mean_absolute_error: 0.2764 - val_loss: 0.0190 - val_mean_absolute_error: 0.1037
# Epoch 56/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2673 - mean_absolute_error: 0.3190 - val_loss: 0.0218 - val_mean_absolute_error: 0.1189
# Epoch 57/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2362 - mean_absolute_error: 0.2673 - val_loss: 0.0168 - val_mean_absolute_error: 0.1002
# Epoch 58/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2401 - mean_absolute_error: 0.2759 - val_loss: 0.0175 - val_mean_absolute_error: 0.1031
# Epoch 59/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2328 - mean_absolute_error: 0.2771 - val_loss: 0.0159 - val_mean_absolute_error: 0.0964
# Epoch 60/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2347 - mean_absolute_error: 0.2689 - val_loss: 0.0211 - val_mean_absolute_error: 0.1166
# Epoch 61/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2340 - mean_absolute_error: 0.2746 - val_loss: 0.0161 - val_mean_absolute_error: 0.0972
# Epoch 62/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2624 - mean_absolute_error: 0.3114 - val_loss: 0.0215 - val_mean_absolute_error: 0.1179
# Epoch 63/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2806 - mean_absolute_error: 0.3197 - val_loss: 0.0169 - val_mean_absolute_error: 0.0977
# Epoch 64/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2423 - mean_absolute_error: 0.2831 - val_loss: 0.0169 - val_mean_absolute_error: 0.0977
# Epoch 65/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2543 - mean_absolute_error: 0.3068 - val_loss: 0.0331 - val_mean_absolute_error: 0.1518
# Epoch 66/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2435 - mean_absolute_error: 0.2839 - val_loss: 0.0166 - val_mean_absolute_error: 0.0994
# Epoch 67/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2323 - mean_absolute_error: 0.2661 - val_loss: 0.0189 - val_mean_absolute_error: 0.1090
# Epoch 68/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2530 - mean_absolute_error: 0.2987 - val_loss: 0.0159 - val_mean_absolute_error: 0.0962
# Epoch 69/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2631 - mean_absolute_error: 0.3081 - val_loss: 0.0202 - val_mean_absolute_error: 0.1134
# Epoch 70/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2344 - mean_absolute_error: 0.2703 - val_loss: 0.0210 - val_mean_absolute_error: 0.1162
# Epoch 71/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2611 - mean_absolute_error: 0.3168 - val_loss: 0.0160 - val_mean_absolute_error: 0.0961
# Epoch 72/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2539 - mean_absolute_error: 0.2915 - val_loss: 0.0301 - val_mean_absolute_error: 0.1440
# Epoch 73/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2698 - mean_absolute_error: 0.3479 - val_loss: 0.0285 - val_mean_absolute_error: 0.1392
# Epoch 74/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2406 - mean_absolute_error: 0.2879 - val_loss: 0.0174 - val_mean_absolute_error: 0.0993
# Epoch 75/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2310 - mean_absolute_error: 0.2824 - val_loss: 0.0162 - val_mean_absolute_error: 0.0978
# Epoch 76/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2335 - mean_absolute_error: 0.2685 - val_loss: 0.0202 - val_mean_absolute_error: 0.1136
# Epoch 77/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2487 - mean_absolute_error: 0.2953 - val_loss: 0.0222 - val_mean_absolute_error: 0.1138
# Epoch 78/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2443 - mean_absolute_error: 0.2897 - val_loss: 0.0184 - val_mean_absolute_error: 0.1073
# Epoch 79/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2304 - mean_absolute_error: 0.2689 - val_loss: 0.0159 - val_mean_absolute_error: 0.0962
# Epoch 80/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2479 - mean_absolute_error: 0.2967 - val_loss: 0.0320 - val_mean_absolute_error: 0.1488
# Epoch 81/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2597 - mean_absolute_error: 0.3056 - val_loss: 0.0171 - val_mean_absolute_error: 0.1018
# Epoch 82/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2344 - mean_absolute_error: 0.2671 - val_loss: 0.0200 - val_mean_absolute_error: 0.1130
# Epoch 83/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2352 - mean_absolute_error: 0.2702 - val_loss: 0.0209 - val_mean_absolute_error: 0.1161
# Epoch 84/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2431 - mean_absolute_error: 0.2839 - val_loss: 0.0161 - val_mean_absolute_error: 0.0962
# Epoch 85/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2313 - mean_absolute_error: 0.2706 - val_loss: 0.0171 - val_mean_absolute_error: 0.0984
# Epoch 86/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2392 - mean_absolute_error: 0.2847 - val_loss: 0.0166 - val_mean_absolute_error: 0.1001
# Epoch 87/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2360 - mean_absolute_error: 0.2686 - val_loss: 0.0194 - val_mean_absolute_error: 0.1105
# Epoch 88/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2347 - mean_absolute_error: 0.2772 - val_loss: 0.0159 - val_mean_absolute_error: 0.0963
# Epoch 89/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2375 - mean_absolute_error: 0.2872 - val_loss: 0.0171 - val_mean_absolute_error: 0.1023
# Epoch 90/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2337 - mean_absolute_error: 0.2805 - val_loss: 0.0159 - val_mean_absolute_error: 0.0966
# Epoch 91/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2373 - mean_absolute_error: 0.2823 - val_loss: 0.0161 - val_mean_absolute_error: 0.0963
# Epoch 92/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2736 - mean_absolute_error: 0.3210 - val_loss: 0.0281 - val_mean_absolute_error: 0.1383
# Epoch 93/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2682 - mean_absolute_error: 0.3240 - val_loss: 0.0179 - val_mean_absolute_error: 0.1006
# Epoch 94/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2399 - mean_absolute_error: 0.2948 - val_loss: 0.0299 - val_mean_absolute_error: 0.1436
# Epoch 95/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3134 - mean_absolute_error: 0.3826 - val_loss: 0.0160 - val_mean_absolute_error: 0.0971
# Epoch 96/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2479 - mean_absolute_error: 0.2797 - val_loss: 0.0167 - val_mean_absolute_error: 0.1004
# Epoch 97/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2429 - mean_absolute_error: 0.2880 - val_loss: 0.0167 - val_mean_absolute_error: 0.1002
# Epoch 98/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2381 - mean_absolute_error: 0.2768 - val_loss: 0.0169 - val_mean_absolute_error: 0.1012
# Epoch 99/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2325 - mean_absolute_error: 0.2725 - val_loss: 0.0167 - val_mean_absolute_error: 0.1007
# Epoch 100/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2304 - mean_absolute_error: 0.2677 - val_loss: 0.0262 - val_mean_absolute_error: 0.1326

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 18/18 [==============================] - 0s 851us/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 3/3 [==============================] - 0s 1ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
